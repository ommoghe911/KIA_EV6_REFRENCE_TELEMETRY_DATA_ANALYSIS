# %% [markdown]
# BASIC ENVIORNMENTAL SETUP

# %%
import pandas as pd
import numpy as np
print("EV6 DATA PROJECT STARTED")
# Out:
# EV6 DATA PROJECT STARTED

# %%
df_ev6 = pd.read_csv("../A_DATASOURCE/RAWDATASET/Kia_EV6_Ref_Dataset_Raw_12000.csv")

# %%
df= df_ev6.copy()

# %% [markdown]
# BASELINE DATA UNDERSTANDING

# %%
df.shape
print("ROWS,",df.shape[0])
print('COLOUMNS,',df.shape[1])
# Out:
# ROWS, 12080
# COLOUMNS, 50

# %% [markdown]
# CREATING THE COPY OF DATASET (ALWAYS HAVE A RAW DATA UNTOUCHED)

# %%
df.columns.tolist()
# Out:
# ['Session_ID',
#  'Timestamp',
#  'Epoch',
#  'Source_Log',
#  'Vehicle_Speed_kmh',
#  'Speed_mps',
#  'Accel_X_mps2',
#  'Accel_Y_mps2',
#  'Accel_Z_mps2',
#  'Altitude_m',
#  'Road_Grade_pct',
#  'Heading_deg',
#  'Pitch_deg',
#  'Roll_deg',
#  'Aero_Force_N',
#  'Rolling_Resistance_N',
#  'Grade_Force_N',
#  'Inertial_Force_N',
#  'Estimated_Road_Load_N',
#  'Estimated_Wheel_Power_kW',
#  'Estimated_Wheel_Torque_Nm',
#  'Estimated_Motor_Torque_Nm',
#  'Battery_Voltage_V',
#  'Battery_Current_A',
#  'Battery_Power_kW',
#  'Available_Charge_Power_kW',
#  'Available_Discharge_Power_kW',
#  'Battery_SOC_pct',
#  'SOC_Display_pct',
#  'Battery_SOH_pct',
#  'Battery_Max_Temp_C',
#  'Battery_Min_Temp_C',
#  'Battery_Temp_C',
#  'Battery_Temp_Spread_C',
#  'Max_Cell_Voltage_V',
#  'Min_Cell_Voltage_V',
#  'Cell_Voltage_Spread_V',
#  'Ambient_Temp_C',
#  'Distance_Total_km',
#  'Distance_Trip_km',
#  'TPMS_FL',
#  'TPMS_FR',
#  'TPMS_RL',
#  'TPMS_RR',
#  'TPMS_Avg',
#  'Latitude_deg',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12080 entries, 0 to 12079
# Data columns (total 50 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Session_ID                           12080 non-null  object
#  1   Timestamp                            12080 non-null  object
#  2   Epoch                                11953 non-null  float64
#  3   Source_Log                           12080 non-null  object
#  4   Vehicle_Speed_kmh                    11928 non-null  float64
#  5   Speed_mps                            11953 non-null  float64
#  6   Accel_X_mps2                         11987 non-null  float64
#  7   Accel_Y_mps2                         11987 non-null  float64
#  8   Accel_Z_mps2                         11987 non-null  float64
#  9   Altitude_m                           11953 non-null  float64
#  10  Road_Grade_pct                       12005 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                                        count          mean           std  \
# Epoch                                11953.0  1.672802e+09  1.298067e+07
# Vehicle_Speed_kmh                    11928.0  1.401156e+01  1.066230e+01
# Speed_mps                            11953.0  3.891601e+00  2.960378e+00
# Accel_X_mps2                         11987.0  7.966188e-03  7.921482e-01
# Accel_Y_mps2                         11987.0  5.483705e-01  4.486720e-01
# Accel_Z_mps2                         11987.0  1.002996e+01  7.846990e-02
# Altitude_m                           11953.0  9.741477e+01  6.822257e+01
# Road_Grade_pct                       12005.0  2.829025e-01  6.666826e+00
# Heading_deg                          11953.0  1.637343e+02  9.219178e+01
# Pitch_deg                            11953.0 -3.494415e-02  1.285161e+00
# Roll_deg                             11953.0  3.437298e-01  1.391004e+00
# Aero_Force_N                         12080.0  9.107089e+00  1.129653e+01
# ...

# %%
pd.set_option('display.max_rows',None)
df.isnull().sum()
# Out:
# Session_ID                                0
# Timestamp                                 0
# Epoch                                   127
# Source_Log                                0
# Vehicle_Speed_kmh                       152
# Speed_mps                               127
# Accel_X_mps2                             93
# Accel_Y_mps2                             93
# Accel_Z_mps2                             93
# Altitude_m                              127
# Road_Grade_pct                           75
# Heading_deg                             127
# Pitch_deg                               127
# Roll_deg                                127
# Aero_Force_N                              0
# Rolling_Resistance_N                      0
# Grade_Force_N                             0
# Inertial_Force_N                          0
# Estimated_Road_Load_N                     0
# Estimated_Wheel_Power_kW                  0
# Estimated_Wheel_Torque_Nm                 0
# ...

# %% [markdown]
#  MISSING DATA CHECKING

# %%
missing_report = pd.DataFrame({
    'Missing_Count': df.isnull().sum(),
    'Missing_Percentage': (df.isnull().mean() * 100).round(2)
})

missing_report.sort_values('Missing_Percentage', ascending=False)
missing_report.sort_values('Missing_Count',ascending=False)

# %% [markdown]
# ------DUPLICATE CHECKS----

# %%
df.duplicated().sum()
# Out:
# np.int64(61)

# %%
df.duplicated(
    subset=["Session_ID", "Timestamp"]
).sum()
# Out:
# np.int64(82)

# %%
df[
    df.duplicated(
    subset=["Session_ID","Timestamp"],
    keep = False
)]

# %%
df[df.duplicated()]
#actual rows print which are duplicate.

# %%
df[df.duplicated(keep=False)]  # this is for keeping original plus duplicate

# %%
df["Session_ID"].nunique()
# Out:
# 150

# %%
pd.set_option('display.max_rows',None)
df["Session_ID"].value_counts()

# %%
df["Drive_Context"].value_counts()
# Out:
# Drive_Context
# Urban            9134
# Stop_or_Crawl    2819
# Name: count, dtype: int64
